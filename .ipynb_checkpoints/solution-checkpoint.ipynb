# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('titanic/train.csv')
test_df = pd.read_csv('titanic/test.csv')
survived = train_df.Survived.copy()
df_list = [train_df,test_df]
#all_df = pd.concat([train_df,test_df],axis = 0)
#all_df.info()

# %%
sex_map = {'male':0,'female':1}
for df in df_list:
    df['Title'] = df['Name'].str.split(',',expand = True)[1].str.split('.',expand = True)[0].str.strip(' ')
    #df.Age.fillna(value = df.Age.mean(),inplace = True)
    #df.Embarked.fillna(value = df.Embarked.mode()[0],inplace = True)
    df['FamilySize']= df['SibSp']+df['Parch']+1
    df.drop(['Cabin','Ticket'],axis = 1,inplace = True)
    df.Sex = df.Sex.map(sex_map).astype(int)
    

test_df.info()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null int64
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           417 non-null float64
# Embarked       418 non-null object
# Title          418 non-null object
# FamilySize     418 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null int64
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# Title          891 non-null object
# FamilySize     891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.6+ KB

# %%
title_age = train_df[['Title','Age']].groupby('Title').mean().astype(int)
print(title_age)
# Out:
#               Age
# Title
# Capt           70
# Col            58
# Don            40
# Dr             42
# Jonkheer       38
# Lady           48
# Major          48
# Master          4
# Miss           21
# Mlle           24
# Mme            24
# Mr             32
# Mrs            35
# Ms             28
# Rev            43
# Sir            49
# the Countess   33

# %%
print(test_df.groupby('Title').size())
print(train_df.groupby('Title').size())
# Out:
# Title
# 4           4
# 21         15
# 32         57
# 35         10
# Master     17
# Misc        6
# Miss       64
# Mr        183
# Mrs        62
# dtype: int64
# Title
# 4           4
# 21         36
# 32        119
# 35         17
# 45          1
# Master     36
# Misc       22
# Miss      149
# Mr        398
# Mrs       109
# dtype: int64

# %%
for df in df_list:
    df['Title'] = df['Title'].replace(['Lady', 'the Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],'Misc',regex=True)
    df['Title'] = df['Title'].replace('Mlle','Miss',regex=True)
    df['Title'] = df['Title'].replace('Mme','Mrs',regex=True)
    df['Title'] = df['Title'].replace('Ms','Miss',regex=True)
test_df.loc[(test_df['Title']=='Misca'),'Title'] = 'Misc'
test_df.iloc[414]
# Out:
# PassengerId                            1306
# Pclass                                    1
# Name           Oliva y Ocana, Dona. Fermina
# Sex                                       1
# Age                                      39
# SibSp                                     0
# Parch                                     0
# Fare                                  108.9
# Embarked                                  C
# Title                                  Misc
# FamilySize                                1
# Name: 414, dtype: object

# %%
train_df[['Title','Age']].groupby('Title').mean().astype(int)
# Out:
#         Age
# Title
# Master    4
# Misc     45
# Miss     21
# Mr       32
# Mrs      35

# %%
for df in df_list:
    df.loc[(df['Title'] == 'Master') & (df['Age'].isnull()),'Age'] = 4
    df.loc[(df['Title'] == 'Misc') & (df['Age'].isnull()),'Age'] = 45
    df.loc[(df['Title'] == 'Miss') & (df['Age'].isnull()),'Age'] = 21
    df.loc[(df['Title'] == 'Mr') & (df['Age'].isnull()),'Age'] = 32
    df.loc[(df['Title'] == 'Mrs') & (df['Age'].isnull()),'Age']=35

# %%
train_df.info()
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# Title          891 non-null object
# FamilySize     891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           417 non-null float64
# Embarked       418 non-null object
# Title          418 non-null object
# FamilySize     418 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %%
test_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10            32      32                                                 32
# 11           903       1                         Jones, Mr. Charles Cresson
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13           905       2                               Howard, Mr. Benjamin
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15           907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 16           908       2                                  Keane, Mr. Daniel
# 17           909       3                                  Assaf, Mr. Gerios
# 18           910       3                       Ilmakangas, Miss. Ida Livija
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 20           912       1                             Rothschild, Mr. Martin
# 21           913       3                          Olsen, Master. Artur Karl
# 22            35      35                                                 35
# 23           915       1                    Williams, Mr. Richard Norris II
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25           917       3                            Robins, Mr. Alexander A
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 27           919       3                                  Daher, Mr. Shedid
# 28           920       1                            Brady, Mr. John Bertram
# 29            32      32                                                 32
# ..           ...     ...                                                ...
# 388         1280       3                               Canavan, Mr. Patrick
# 389         1281       3                        Palsson, Master. Paul Folke
# 390         1282       1                         Payne, Mr. Vivian Ponsonby
# 391         1283       1     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 392         1284       3                      Abbott, Master. Eugene Joseph
# 393         1285       2                               Gilbert, Mr. William
# 394         1286       3                           Kink-Heilmann, Mr. Anton
# 395         1287       1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 396         1288       3                               Colbert, Mr. Patrick
# 397         1289       1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 398         1290       3                     Larsson-Rondberg, Mr. Edvard A
# 399         1291       3                           Conlon, Mr. Thomas Henry
# 400         1292       1                            Bonnell, Miss. Caroline
# 401         1293       2                                    Gale, Mr. Harry
# 402         1294       1                     Gibson, Miss. Dorothy Winifred
# 403         1295       1                             Carrau, Mr. Jose Pedro
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                          Ware, Mr. William Jeffery
# 407         1299       1                         Widener, Mr. George Dunton
# 408           21      21                                                 21
# 409         1301       3                          Peacock, Miss. Treasteall
# 410           21      21                                                 21
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                     Henriksson, Miss. Jenny Lovisa
# 413           32      32                                                 32
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416           32      32                                                 32
# 417            4       4                                                  4
#
#      Sex   Age  SibSp  Parch      Fare Embarked   Title  FamilySize
# 0      0  34.5      0      0    7.8292        Q      Mr           1
# 1      1  47.0      1      0    7.0000        S     Mrs           2
# 2      0  62.0      0      0    9.6875        Q      Mr           1
# 3      0  27.0      0      0    8.6625        S      Mr           1
# 4      1  22.0      1      1   12.2875        S     Mrs           3
# 5      0  14.0      0      0    9.2250        S      Mr           1
# 6      1  30.0      0      0    7.6292        Q    Miss           1
# 7      0  26.0      1      1   29.0000        S      Mr           3
# 8      1  18.0      0      0    7.2292        C     Mrs           1
# 9      0  21.0      2      0   24.1500        S      Mr           3
# 10    32  32.0     32     32   32.0000       32      32          32
# 11     0  46.0      0      0   26.0000        S      Mr           1
# 12     1  23.0      1      0   82.2667        S     Mrs           2
# 13     0  63.0      1      0   26.0000        S      Mr           2
# 14     1  47.0      1      0   61.1750        S     Mrs           2
# 15     1  24.0      1      0   27.7208        C     Mrs           2
# 16     0  35.0      0      0   12.3500        Q      Mr           1
# 17     0  21.0      0      0    7.2250        C      Mr           1
# 18     1  27.0      1      0    7.9250        S    Miss           2
# 19     1  45.0      0      0    7.2250        C     Mrs           1
# 20     0  55.0      1      0   59.4000        C      Mr           2
# 21     0   9.0      0      1    3.1708        S  Master           2
# 22    35  35.0     35     35   35.0000       35      35          35
# 23     0  21.0      0      1   61.3792        C      Mr           2
# 24     1  48.0      1      3  262.3750        C     Mrs           5
# 25     0  50.0      1      0   14.5000        S      Mr           2
# 26     1  22.0      0      1   61.9792        C    Miss           2
# 27     0  22.5      0      0    7.2250        C      Mr           1
# 28     0  41.0      0      0   30.5000        S      Mr           1
# 29    32  32.0     32     32   32.0000       32      32          32
# ..   ...   ...    ...    ...       ...      ...     ...         ...
# 388    0  21.0      0      0    7.7500        Q      Mr           1
# 389    0   6.0      3      1   21.0750        S  Master           5
# 390    0  23.0      0      0   93.5000        S      Mr           1
# 391    1  51.0      0      1   39.4000        S     Mrs           2
# 392    0  13.0      0      2   20.2500        S  Master           3
# 393    0  47.0      0      0   10.5000        S      Mr           1
# 394    0  29.0      3      1   22.0250        S      Mr           5
# 395    1  18.0      1      0   60.0000        S     Mrs           2
# 396    0  24.0      0      0    7.2500        Q      Mr           1
# 397    1  48.0      1      1   79.2000        C     Mrs           3
# 398    0  22.0      0      0    7.7750        S      Mr           1
# 399    0  31.0      0      0    7.7333        Q      Mr           1
# 400    1  30.0      0      0  164.8667        S    Miss           1
# 401    0  38.0      1      0   21.0000        S      Mr           2
# 402    1  22.0      0      1   59.4000        C    Miss           2
# 403    0  17.0      0      0   47.1000        S      Mr           1
# 404    0  43.0      1      0   27.7208        C      Mr           2
# 405    0  20.0      0      0   13.8625        C      Mr           1
# 406    0  23.0      1      0   10.5000        S      Mr           2
# 407    0  50.0      1      1  211.5000        C      Mr           3
# 408   21  21.0     21     21   21.0000       21      21          21
# 409    1   3.0      1      1   13.7750        S    Miss           3
# 410   21  21.0     21     21   21.0000       21      21          21
# 411    1  37.0      1      0   90.0000        Q     Mrs           2
# 412    1  28.0      0      0    7.7750        S    Miss           1
# 413   32  32.0     32     32   32.0000       32      32          32
# 414    1  39.0      0      0  108.9000        C    Misc           1
# 415    0  38.5      0      0    7.2500        S      Mr           1
# 416   32  32.0     32     32   32.0000       32      32          32
# 417    4   4.0      4      4    4.0000        4       4           4
#
# [418 rows x 11 columns]

# %%
train_df[['Sex','Survived']].groupby('Sex').mean()
# Out:
#      Survived
# Sex
# 0    0.188908
# 1    0.742038

# %%
g = sns.FacetGrid(train_df,col='Survived',row = 'Sex')
g.map(plt.hist,'Age')

# %%
pd.pivot_table(data = train_df,columns = 'Sex',values = 'Survived',index = ['Pclass','Embarked'])
train_df[['Pclass','Survived']].groupby('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
train_df[['Embarked','Survived']].groupby('Embarked').mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.339009

# %%
train_df[['FamilySize',"Survived"]].groupby('FamilySize').mean()
# Out:
#             Survived
# FamilySize
# 1           0.303538
# 2           0.552795
# 3           0.578431
# 4           0.724138
# 5           0.200000
# 6           0.136364
# 7           0.333333
# 8           0.000000
# 11          0.000000

# %%
## Classify family size into different sizes {alone:1,small:(2-4),medium(5-6),large(>6)}
def familyGroup(df):
    bins = [0,1,4,6,15]
    groupNames = [1,2,3,4] #alone,small,medium,large
    cat = pd.cut(df.FamilySize,bins,labels = groupNames)
    df.FamilySize = cat
    return df

for df in df_list:
    df = familyGroup(df)
train_df[['FamilySize','Survived']].groupby('FamilySize').mean()
# Out:
#             Survived
# FamilySize
# 1           0.303538
# 2           0.578767
# 3           0.162162
# 4           0.160000

# %%
fig,ax = plt.subplots(1,2)
ax[0]= train_df.Fare.plot.box()
ax[1] =test_df.Fare.plot.box()

# %%
def fareGroup(df):
    groupName = [1,2,3,4]
    cat = pd.qcut(df.Fare,4,labels = groupName)
    df.Fare = cat
    return df

# %%
for df in df_list:
    df = fareGroup(df)
train_df[['Fare','Survived']].groupby('Fare').mean()
# Out:
#       Survived
# Fare
# 1     0.197309
# 2     0.303571
# 3     0.454955
# 4     0.581081

# %%
train_df.Age.describe()
test_df.Age.describe()
# Out:
# count    418.000000
# mean      30.272590
# std       12.634534
# min        0.170000
# 25%       23.000000
# 50%       30.272590
# 75%       35.750000
# max       76.000000
# Name: Age, dtype: float64

# %%
def ageGroup(df):
    bins = [0,10,20,30,40,100]
    group = [0,1,2,3,4] #child,youth,young-adult,adult,senior
    cat = pd.cut(df.Age,bins,labels=group)
    df.Age = cat
    return df
for df in df_list:
    df = ageGroup(df)
train_df[['Age','Survived']].groupby('Age').mean()
# Out:
#      Survived
# Age
# 0    0.593750
# 1    0.382609
# 2    0.334152
# 3    0.445161
# 4    0.366667

# %%
title_code = {'Mr':1,'Misc':2,'Master':3,'Miss':4,'Mrs':5}
embarked_code = {'S':1,'Q':2,'C':3}
pclass_code = {3:1,2:2,1:3}
family_code = {4:1,3:2,1:3,2:4}
age_code = {2:1,4:2,1:3,3:4,0:5}
fare_code = {1:4,2:3,3:2,4:1}
for df in df_list:
    df.Title = df.Title.map(title_code).astype(int)
    df.Pclass = df.Pclass.map(pclass_code)
    df.Embarked = df.Embarked.map(embarked_code)
    df.FamilySize = df.FamilySize.map(family_code)
    df.Age = df.Age.map(age_code)
    df.Fare = df.Fare.map(fare_code)
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       1
# 1            2         1       3
# 2            3         1       1
# 3            4         1       3
# 4            5         0       1
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1    4      1      0
# 2                             Heikkinen, Miss. Laina    1    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1    4      1      0
# 4                           Allen, Mr. William Henry    0    4      0      0
#
#    Fare  Embarked  Title  FamilySize
# 0     4         1      1           4
# 1     1         3      5           4
# 2     3         1      4           3
# 3     1         1      5           4
# 4     3         1      1           3

# %%
sns.heatmap(data = train_df.corr(),annot = True)

# %%
for df in df_list:
    df = df.drop(['Parch','SibSp'],axis = 1)
input_features = ['Pclass','Age','Fare','Embarked','Title','FamilySize']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

train_input = train_df[input_features]
test_input = test_df[input_features]
X_train,X_test,y_train,y_test = train_test_split(train_input,survived)

# %%
clf  = RandomForestClassifier(random_state = 2019)
param = {'n_estimators':[4,6,9],
         'max_features':['log2','sqrt','auto'],
         'criterion':['entropy','gini'],
        'max_depth':[2,3,5,10],
        'min_samples_split':[2,3,5],
        'min_samples_leaf':[1,5,8]
        }
grid = GridSearchCV(clf,param,scoring = 'accuracy')
grid = grid.fit(X_train,y_train)

clf = grid.best_estimator_
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
print(accuracy_score(y_test,pred))
from sklearn.model_selection import cross_val_score
print(cross_val_score(clf,train_input,survived,cv = 5))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=3,
#                        min_weight_fraction_leaf=0.0, n_estimators=9,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
clf = AdaBoostClassifier(random_state = 2019)
param = {'n_estimators':[50,70,90],
        'learning_rate':[0.01,0.1,1],
        'algorithm':['SAMME','SMAAE.R']
        }
grid = GridSearchCV(clf,param,scoring = 'accuracy')
grid = grid.fit(X_train,y_train)

clf = grid.best_estimator_
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
print(accuracy_score(y_test,pred))
from sklearn.model_selection import cross_val_score
print(cross_val_score(clf,train_input,survived,cv = 5))
# Out:
# 0.8295964125560538

# %%
clf = GradientBoostingClassifier(random_state = 2019)
param = {'n_estimators':[50,100,150],
        'min_samples_split':[2,3,4],
        'max_depth':[3,4,5],
        'max_features':['auto','sqrt','log2'],
        'min_samples_leaf':[1,5,8]}
grid = GridSearchCV(clf,param,scoring = 'accuracy')
grid = grid.fit(X_train,y_train)

clf = grid.best_estimator_
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
print(accuracy_score(y_test,pred))
from sklearn.model_selection import cross_val_score
print(cross_val_score(clf,train_input,survived,cv = 5))
# Out:
# [0.83240223 0.82681564 0.8258427  0.79213483 0.82485876]

# %%
test_input.info()
test_df.iloc[414]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 5 columns):
# Pclass        418 non-null int64
# Age           418 non-null int64
# Embarked      418 non-null int64
# Title         418 non-null int64
# FamilySize    418 non-null int64
# dtypes: int64(5)
# memory usage: 16.4 KB
# PassengerId                            1306
# Pclass                                    3
# Name           Oliva y Ocana, Dona. Fermina
# Sex                                       1
# Age                                       4
# SibSp                                     0
# Parch                                     0
# Embarked                                  3
# Title                                     2
# FamilySize                                3
# Survived                                  1
# Name: 414, dtype: object

# %%
test_df['Survived'] = clf.predict(test_input)
output = pd.concat([test_df['PassengerId'],test_df['Survived']],axis = 1)
output.to_csv('titanic/random_forest.csv',index = False)
